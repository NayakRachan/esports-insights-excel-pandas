# %%
import pandas as pd
# !pip install openpyxl

# %%
df  = pd.read_excel("/content/Esports Data.xlsx")
df.head(1)
# Out:
#                 Timestamp   What is your age group?   What is your gender?  \
# 0 2025-04-07 15:04:27.741                35 and above               Female
#
#     Are you familiar with eSports?    \
# 0                                Yes
#
#     How often do you watch eSports tournaments?    \
# 0                                           Never
#
#      What type of eSports games do you prefer?    \
# 0  First-person shooters (e.g., CS:GO, Valorant)
#
#     Which platform do you usually use to watch eSports?    \
# 0                                             Twitch
#
#   Do you follow any eSports teams or players?
# 0                                         Yes

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'], dayfirst=True)
df.head(1)
# Out:
#                 Timestamp   What is your age group?   What is your gender?  \
# 0 2025-04-07 15:04:27.741                35 and above               Female
#
#     Are you familiar with eSports?    \
# 0                                Yes
#
#     How often do you watch eSports tournaments?    \
# 0                                           Never
#
#      What type of eSports games do you prefer?    \
# 0  First-person shooters (e.g., CS:GO, Valorant)
#
#     Which platform do you usually use to watch eSports?    \
# 0                                             Twitch
#
#   Do you follow any eSports teams or players?
# 0                                         Yes

# %%
df['date'] = df['Timestamp'].dt.date
df['time'] = df['Timestamp'].dt.time

df.head(2)

df
# Out:
#                    Timestamp   What is your age group?   What is your gender?  \
# 0    2025-04-07 15:04:27.741                35 and above               Female
# 1    2025-04-07 15:04:28.410                       25–34                 Male
# 2    2025-04-07 15:04:29.101                       18–24               Female
# 3    2025-04-07 15:04:29.837                35 and above                Other
# 4    2025-04-07 15:04:30.469                35 and above                Other
# ...                      ...                         ...                  ...
# 1006 2025-04-07 15:14:05.679                       25–34                 Male
# 1007 2025-04-07 15:14:06.184                       18–24               Female
# 1008 2025-04-07 15:14:06.759                    Under 13                Other
# 1009 2025-04-07 15:14:07.268                       25–34                 Male
# 1010 2025-04-17 20:52:02.480                       18–24                 Male
#
# ...

# %%
age_mapping = {
    'Under 13': '0-12',
    '13–17': '13-17',
    '18–24': '18-24',
    '25–34': '25-34',
    '35 and above': '35+'
}

# %%
df.rename(columns={'What is your age group?': 'age_group'}, inplace=True)
df.head(1)
# Out:
#                 Timestamp   What is your age group?   What is your gender?  \
# 0 2025-04-07 15:04:27.741                35 and above               Female
#
#     Are you familiar with eSports?    \
# 0                                Yes
#
#     How often do you watch eSports tournaments?    \
# 0                                           Never
#
#      What type of eSports games do you prefer?    \
# 0  First-person shooters (e.g., CS:GO, Valorant)
#
#     Which platform do you usually use to watch eSports?    \
# 0                                             Twitch
#
#   Do you follow any eSports teams or players?        date             time
# 0                                         Yes  2025-04-07  15:04:27.741000

# %%
df
# Out:
#                    Timestamp   What is your age group?   What is your gender?  \
# 0    2025-04-07 15:04:27.741                35 and above               Female
# 1    2025-04-07 15:04:28.410                       25–34                 Male
# 2    2025-04-07 15:04:29.101                       18–24               Female
# 3    2025-04-07 15:04:29.837                35 and above                Other
# 4    2025-04-07 15:04:30.469                35 and above                Other
# ...                      ...                         ...                  ...
# 1006 2025-04-07 15:14:05.679                       25–34                 Male
# 1007 2025-04-07 15:14:06.184                       18–24               Female
# 1008 2025-04-07 15:14:06.759                    Under 13                Other
# 1009 2025-04-07 15:14:07.268                       25–34                 Male
# 1010 2025-04-17 20:52:02.480                       18–24                 Male
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Timestamp', '  What is your age group?  ', 'What is your gender?', '  Are you familiar with eSports?  ', '  How often do you watch eSports tournaments?  ', '  What type of eSports games do you prefer?  ', '  Which platform do you usually use to watch eSports?  ', 'Do you follow any eSports teams or players?', 'date', 'time']

# %%
df.columns = df.columns.str.strip()  # Remove leading/trailing spaces
df.columns = df.columns.str.replace('\n', '', regex=True)  # Remove newlines
df.columns = df.columns.str.replace('\xa0', ' ', regex=True)  # Replace non-breaking spaces

# %%
print(df.columns.tolist())
# Out:
# ['Timestamp', 'What is your age group?', 'What is your gender?', 'Are you familiar with eSports?', 'How often do you watch eSports tournaments?', 'What type of eSports games do you prefer?', 'Which platform do you usually use to watch eSports?', 'Do you follow any eSports teams or players?', 'date', 'time']

# %%
df.rename(columns={'What is your age group?': 'age_group'}, inplace=True)

df.head()
# Out:
#                 Timestamp     age_group What is your gender?  \
# 0 2025-04-07 15:04:27.741  35 and above               Female
# 1 2025-04-07 15:04:28.410         25–34                 Male
# 2 2025-04-07 15:04:29.101         18–24               Female
# 3 2025-04-07 15:04:29.837  35 and above                Other
# 4 2025-04-07 15:04:30.469  35 and above                Other
#
#   Are you familiar with eSports? How often do you watch eSports tournaments?  \
# 0                            Yes                                       Never
# 1                             No                                      Weekly
# 2                             No                                       Daily
# 3                            Yes                                     Monthly
# 4                            Yes                                       Daily
#
#        What type of eSports games do you prefer?  \
# 0  First-person shooters (e.g., CS:GO, Valorant)
# ...

# %%
age_mapping = {
    'Under 13': '0-12',
    '13–17': '13-17',
    '18–24': '18-24',
    '25–34': '25-34',
    '35 and above': '35+'
}

df['age_group_cleaned'] = df['age_group'].map(age_mapping)


df.head(10)
# Out:
#                 Timestamp     age_group What is your gender?  \
# 0 2025-04-07 15:04:27.741  35 and above               Female
# 1 2025-04-07 15:04:28.410         25–34                 Male
# 2 2025-04-07 15:04:29.101         18–24               Female
# 3 2025-04-07 15:04:29.837  35 and above                Other
# 4 2025-04-07 15:04:30.469  35 and above                Other
# 5 2025-04-07 15:04:31.083  35 and above               Female
# 6 2025-04-07 15:04:31.701      Under 13               Female
# 7 2025-04-07 15:04:32.155         18–24               Female
# 8 2025-04-07 15:04:32.775      Under 13                Other
# 9 2025-04-07 15:04:33.369         18–24               Female
#
#   Are you familiar with eSports? How often do you watch eSports tournaments?  \
# 0                            Yes                                       Never
# 1                             No                                      Weekly
# ...

# %%
df.columns.tolist()
# Out:
# ['Timestamp',
#  'age_group',
#  'What is your gender?',
#  'Are you familiar with eSports?',
#  'How often do you watch eSports tournaments?',
#  'What type of eSports games do you prefer?',
#  'Which platform do you usually use to watch eSports?',
#  'Do you follow any eSports teams or players?',
#  'date',
#  'time',
#  'age_group_cleaned']

# %%
df.rename(columns={
    'Timestamp': 'timestamp',
    'age_group': 'age_group',
    'What is your gender?': 'gender',
    'Are you familiar with eSports?': 'familiar_with_esports',
    'How often do you watch eSports tournaments?': 'watch_frequency',
    'What type of eSports games do you prefer?': 'preferred_game_type',
    'Which platform do you usually use to watch eSports?': 'platform_used',
    'Do you follow any eSports teams or players?': 'follows_teams_or_players'
}, inplace=True)

# %%
df.columns.to_list()
# Out:
# ['timestamp',
#  'age_group',
#  'gender',
#  'familiar_with_esports',
#  'watch_frequency',
#  'preferred_game_type',
#  'platform_used',
#  'follows_teams_or_players',
#  'date',
#  'time',
#  'age_group_cleaned']

# %%
df.head(2)
# Out:
#                 timestamp     age_group  gender familiar_with_esports  \
# 0 2025-04-07 15:04:27.741  35 and above  Female                   Yes
# 1 2025-04-07 15:04:28.410         25–34    Male                    No
#
#   watch_frequency                            preferred_game_type  \
# 0           Never  First-person shooters (e.g., CS:GO, Valorant)
# 1          Weekly         MOBA (e.g., Dota 2, League of Legends)
#
#   platform_used follows_teams_or_players        date             time  \
# 0        Twitch                      Yes  2025-04-07  15:04:27.741000
# 1         Other                      Yes  2025-04-07  15:04:28.410000
#
#   age_group_cleaned
# 0               35+
# 1             25-34

# %%
df.preferred_game_type
# Out:
# 0       First-person shooters (e.g., CS:GO, Valorant)
# 1              MOBA (e.g., Dota 2, League of Legends)
# 2                         Sports (e.g., FIFA, NBA 2K)
# 3                Battle Royale (e.g., Fortnite, PUBG)
# 4              MOBA (e.g., Dota 2, League of Legends)
#                             ...
# 1006           Strategy (e.g., StarCraft, Clash Royal
# 1007          Fighting (e.g., Tekken, Street Fighter)
# 1008    First-person shooters (e.g., CS:GO, Valorant)
# 1009             Battle Royale (e.g., Fortnite, PUBG)
# 1010             Battle Royale (e.g., Fortnite, PUBG)
# Name: preferred_game_type, Length: 1011, dtype: object

# %%
df['preferred_game_type_cleaned'] = df['preferred_game_type'].astype(str).str.extract(r'^([^\(]+)')[0].str.strip()
df.preferred_game_type_cleaned
# Out:
# 0       First-person shooters
# 1                        MOBA
# 2                      Sports
# 3               Battle Royale
# 4                        MOBA
#                 ...
# 1006                 Strategy
# 1007                 Fighting
# 1008    First-person shooters
# 1009            Battle Royale
# 1010            Battle Royale
# Name: preferred_game_type_cleaned, Length: 1011, dtype: object

# %%
df.columns.to_list()
# Out:
# ['timestamp',
#  'age_group',
#  'gender',
#  'familiar_with_esports',
#  'watch_frequency',
#  'preferred_game_type',
#  'platform_used',
#  'follows_teams_or_players',
#  'date',
#  'time',
#  'age_group_cleaned',
#  'preferred_game_type_cleaned']

# %%
df.head(4)
# Out:
#    gender familiar_with_esports watch_frequency platform_used  \
# 0  Female                   Yes           Never        Twitch
# 1    Male                    No          Weekly         Other
# 2  Female                    No           Daily       YouTube
# 3   Other                   Yes         Monthly        TikTok
#
#   follows_teams_or_players        date             time age_group_cleaned  \
# 0                      Yes  2025-04-07  15:04:27.741000               35+
# 1                      Yes  2025-04-07  15:04:28.410000             25-34
# 2                       No  2025-04-07  15:04:29.101000             18-24
# 3                       No  2025-04-07  15:04:29.837000               35+
#
#   preferred_game_type_cleaned
# 0       First-person shooters
# 1                        MOBA
# 2                      Sports
# 3               Battle Royale

# %%
df.time
# Out:
# 0       15:04:27.741000
# 1       15:04:28.410000
# 2       15:04:29.101000
# 3       15:04:29.837000
# 4       15:04:30.469000
#              ...
# 1006    15:14:05.679000
# 1007    15:14:06.184000
# 1008    15:14:06.759000
# 1009    15:14:07.268000
# 1010    20:52:02.480000
# Name: time, Length: 1011, dtype: object

# %%
df['time'] = df['time'].apply(lambda x: x.strftime('%H:%M:%S'))

# %%
df.time
# Out:
# 0       15:04:27
# 1       15:04:28
# 2       15:04:29
# 3       15:04:29
# 4       15:04:30
#           ...
# 1006    15:14:05
# 1007    15:14:06
# 1008    15:14:06
# 1009    15:14:07
# 1010    20:52:02
# Name: time, Length: 1011, dtype: object

# %%
df.head(4)
# Out:
#    gender familiar_with_esports watch_frequency platform_used  \
# 0  Female                   Yes           Never        Twitch
# 1    Male                    No          Weekly         Other
# 2  Female                    No           Daily       YouTube
# 3   Other                   Yes         Monthly        TikTok
#
#   follows_teams_or_players        date      time age_group_cleaned  \
# 0                      Yes  2025-04-07  15:04:27               35+
# 1                      Yes  2025-04-07  15:04:28             25-34
# 2                       No  2025-04-07  15:04:29             18-24
# 3                       No  2025-04-07  15:04:29               35+
#
#   preferred_game_type_cleaned
# 0       First-person shooters
# 1                        MOBA
# 2                      Sports
# 3               Battle Royale

# %%
df.rename(columns={'age_group_cleaned': 'age_group'}, inplace=True)

# %%
df.rename(columns={'preferred_game_type_cleaned': 'preffered_game_type'}, inplace=True)

# %%
df.head(3)
# Out:
#    gender familiar_with_esports watch_frequency platform_used  \
# 0  Female                   Yes           Never        Twitch
# 1    Male                    No          Weekly         Other
# 2  Female                    No           Daily       YouTube
#
#   follows_teams_or_players        date      time age_group  \
# 0                      Yes  2025-04-07  15:04:27       35+
# 1                      Yes  2025-04-07  15:04:28     25-34
# 2                       No  2025-04-07  15:04:29     18-24
#
#      preffered_game_type
# 0  First-person shooters
# 1                   MOBA
# 2                 Sports

# %%
df.to_excel("cleaned_esports_data.xlsx", index=False)
